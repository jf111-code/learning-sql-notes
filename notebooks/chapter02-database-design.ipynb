# %% [markdown]
# # Chapter 2 Practice
#
# Creating and Populating a Database

# %% [markdown]
# ## Learning Objectives
#
# - Understand data types
# - Understand primary keys
# - Understand foreign keys
# - Practice table inspection
# - Learn CRUD operations

# %% [markdown]
# ## Sakila Exploration

# %%
SHOW TABLES;

# %%
DESCRIBE film;

# %%
DESCRIBE payment;

# %% [markdown]
# ## Observations
#
# What data types are used?
#
# What columns appear to be primary keys?
#
# What columns appear to be foreign keys?
